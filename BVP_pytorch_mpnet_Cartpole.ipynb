# %%
# import and parameters
import torch
from torch.autograd import Variable
# load data
from tools import data_loader
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append('deps/sparse_rrt')
sys.path.append('.')
from sparse_rrt import _sst_module

seen_N = 1
seen_NP = 1
seen_s = 0
seen_sp = 802
data_folder = './data/cartpole_obs/'
test_data = data_loader.load_test_dataset(seen_N, seen_NP,
                      data_folder, True, seen_s, seen_sp)
obc, obs, paths, sgs, path_lengths, controls, costs = test_data
obs_width = 4.0
step_sz = 0.002
num_steps = 200
dt = 0.002
system = _sst_module.PSOPTCartPole()
cpp_propagator = _sst_module.SystemPropagator()
propagate_dynamics = lambda x, u, t: cpp_propagator.propagate(system, x, u, t)
bound = [30.0, 40.0, 3.141592653589793, 2.0]
def wrap_angle(x, system):
    circular = system.is_circular_topology()
    res = np.array(x)
    for i in range(len(x)):
        if circular[i]:
            # use our previously saved version
            res[i] = x[i] - np.floor(x[i] / (2*np.pi))*(2*np.pi)
            if res[i] > np.pi:
                res[i] = res[i] - 2*np.pi
    return res

# %%
# define dynamics

def dynamics(state, control):
    '''
    implement the function x_dot = f(x,u)
    return the derivative w.r.t. x
    '''
    I = 10
    L = 2.5
    M = 10
    m = 5
    g = 9.8
    H = 0.5  # cart
    # define the name for each state index and action index
    STATE_X, STATE_V, STATE_THETA, STATE_W = 0, 1, 2, 3
    CONTROL_A = 0
    # define boundary
    MIN_X = -30
    MAX_X = 30
    MIN_V = -40
    MAX_V = 40
    MIN_W = -2
    MAX_W = 2
    # obstacle information
    OBS_W = 4
    _v = state[STATE_V]
    _w = state[STATE_W]
    _theta = state[STATE_THETA]
    _a = control[CONTROL_A]
    mass_term = (M + m)*(I + m * L * L) - \
            m * m * L * L * torch.cos(_theta) * torch.cos(_theta)

    state_x = _v
    state_theta = _w
    mass_term = (1.0 / mass_term)
    # normalize: added (1/max_X) term
    #deriv[STATE_V] = (1/MAX_X)*((I + m * L * L)* \
    state_v = ((I + m * L * L)* \
        (_a + m * L * _w * _w * torch.sin(_theta)) + \
        m * m * L * L * torch.cos(_theta) * torch.sin(_theta) * g) * mass_term
    state_w = ((-m * L * torch.cos(_theta)) * \
        (_a + m * L * _w * _w * torch.sin(_theta))+(M + m) * \
        (-m * g * L * torch.sin(_theta))) * mass_term
    deriv = torch.stack([state_x, state_v, state_theta, state_w])
    return deriv


    
def enforce_state_bounds(state):
    '''

    check if state satisfies the bound
    apply threshold to velocity and angle
    return a new state toward which the bound has been enforced
    '''
    I = 10
    L = 2.5
    M = 10
    m = 5
    g = 9.8
    H = 0.5  # cart
    # define the name for each state index and action index
    STATE_X, STATE_V, STATE_THETA, STATE_W = 0, 1, 2, 3
    CONTROL_A = 0
    # define boundary
    MIN_X = -30
    MAX_X = 30
    MIN_V = -40
    MAX_V = 40
    MIN_W = -2
    MAX_W = 2
    # obstacle information
    OBS_W = 4
    """
    if state[STATE_V] < MIN_V/30.:
        new_state[STATE_V] = MIN_V/30.
    elif state[STATE_V] > MAX_V/30.:
        new_state[STATE_V] = MAX_V/30.
    """
    if(state[STATE_X]<MIN_X):
        state[STATE_X]=MIN_X
    elif(state[STATE_X]>MAX_X):
        state[STATE_X]=MAX_X

    if state[STATE_V] < MIN_V:
        state[STATE_V] = MIN_V
    elif state[STATE_V] > MAX_V:
        state[STATE_V] = MAX_V

    if state[STATE_THETA] < -np.pi:
        state[STATE_THETA] += 2*np.pi
    elif state[STATE_THETA] > np.pi:
        state[STATE_THETA] -= 2*np.pi

    if state[STATE_W] < MIN_W:
        state[STATE_W] = MIN_W
    elif state[STATE_W] > MAX_W:
        state[STATE_W] = MAX_W
    return state



def enforce_control_bounds(control):
    MIN_TORQUE, MAX_TORQUE = -300., 300.
    if control[0] < MIN_TORQUE:
        control[0] = MIN_TORQUE
    if control[0] > MAX_TORQUE:
        control[0] = MAX_TORQUE
    return control

    


def IsInCollision(x, obc, obc_width=4.):
    I = 10
    L = 2.5
    M = 10
    m = 5
    g = 9.8
    H = 0.5

    STATE_X = 0
    STATE_V = 1
    STATE_THETA = 2
    STATE_W = 3
    CONTROL_A = 0

    MIN_X = -30
    MAX_X = 30
    MIN_V = -40
    MAX_V = 40
    MIN_W = -2
    MAX_W = 2

    
    if x[0] < MIN_X or x[0] > MAX_X:
        return True
    
    H = 0.5
    pole_x1 = x[0]
    pole_y1 = H
    pole_x2 = x[0] + L * np.sin(x[2])
    pole_y2 = H + L * np.cos(x[2])

    
    for i in range(len(obc)):
        for j in range(0, 8, 2):
            x1 = obc[i][j]
            y1 = obc[i][j+1]
            x2 = obc[i][(j+2) % 8]
            y2 = obc[i][(j+3) % 8]
            if line_line_cc(pole_x1, pole_y1, pole_x2, pole_y2, x1, y1, x2, y2):
                return True
    return False

def line_line_cc(x1, y1, x2, y2, x3, y3, x4, y4):
    uA = ((x4-x3)*(y1-y3) - (y4-y3)*(x1-x3)) / ((y4-y3)*(x2-x1) - (x4-x3)*(y2-y1))
    uB = ((x2-x1)*(y1-y3) - (y2-y1)*(x1-x3)) / ((y4-y3)*(x2-x1) - (x4-x3)*(y2-y1))
    if uA >= 0. and uA <= 1. and uB >= 0. and uB <= 1.:
        # intersection
        return True
    # collision free
    return False

# %%
def dynamic_loss(x0, u0, x1, num_dt, dt):
    bound = torch.DoubleTensor([30.0, 40.0, 3.141592653589793, 2.0])
    x_target = x0
    for i in range(num_dt):
        x_target = dynamics(x_target, u0) * dt + x_target
    
    #x_target_norm = x_target / bound
    #x1_norm = x1 / bound  # normalize everything to -1 ~ 1
    #return torch.mean((x_target_norm - x1_norm) ** 2) / 4
    res = x_target - x1
    circular = system.is_circular_topology()

    for i in range(len(x_target)):
        if circular[i]:
            if res[i] > np.pi:
                res[i] = res[i] - 2*np.pi
            if res[i] < -np.pi:
                res[i] = res[i] + 2*np.pi
    #res = (x_target - x1) ** 2
    #res = res ** 2

    res = torch.abs(res)
    #cond = res < 1
    #l = torch.where(cond, 0.5 * res ** 2, res)
    #l = torch.mean(l, dim=0)  # sum alone the batch dimension, now the dimension is the same as input dimension
    res = res / bound
    #res = res ** 2
    res = torch.mean(res)
    #if res <= 1.:
    #    res = res * (1 / res.detach().data.item())
    return res

def bvp_solve_naive(x_init, u_init, dt, num_opt_steps, num_intermediate_steps):
    # there are num_steps - 1 intermediate nodes
    x0 = torch.from_numpy(x_init[0])
    xG = torch.from_numpy(x_init[-1])
    xs = [torch.from_numpy(x_init[i]) for i in range(len(x_init))]
    us = [torch.from_numpy(u_init[i]) for i in range(len(u_init))]
    x0 = Variable(x0, requires_grad=False)
    xG = Variable(xG, requires_grad=False)
    
    xs = [Variable(xs[i], requires_grad=False) for i in range(len(xs))]
    us = [Variable(us[i], requires_grad=True) for i in range(len(us))]
    
    #us = [Variable(us[i], requires_grad=True) for i in range(len(us))]
    #opt_algo = torch.optim.Adagrad
    opt_algo = torch.optim.LBFGS
    
    opt = opt_algo(us, lr=1e1, max_iter=2, history_size=20, tolerance_change=1e-9)#, lr=1e-1)
    
    
    max_iter = 40
    for opt_iter in range(max_iter):        
        # forward pass
        #print('iteration ', opt_iter)
        #for i in range(len(us)-2, -1, -1):
        def closure():
            for i in range(len(us)-1):
                for j in range(num_intermediate_steps):
                    xs[i+1] = dt*dynamics(xs[i], us[i]) + xs[i]
            loss = dynamic_loss(xs[-2], us[-1], xs[-1], 1, dt)
            print('loss: ', loss.item())

            opt.zero_grad()
            if loss.item() > 1e-3:
                loss.backward()
            us[1].retain_grad()
            print(us[1].grad)
            return loss
        opt.step(closure)
        with torch.no_grad():
            for i in range(len(us)):
                enforce_state_bounds(xs[i])
                enforce_control_bounds(us[i])

    x0_res = np.array([x0.data.numpy()])
    xs_res = xs[1:-1]
    xs_res = np.array([xs[i].detach().data.numpy() for i in range(len(xs_res))])
    xT_res = np.array([xG.data.numpy()])
    us_res = np.array([us[i].detach().data.numpy() for i in range(len(us))]) 
    
    #print(x0_res.shape)
    #print(xs_res.shape)
    #print(xT_res.shape)
    x_res = np.concatenate([x0_res, xs_res, xT_res], 0)
    u_res = us_res
    return x_res, u_res

# %%
import torch.nn as nn
from tools.utility import *
from model import mlp_cartpole
from model.AE import CAE_cartpole_voxel_2d
from model.mpnet import KMPNet
import os
from plan_utility import cart_pole_obs

# load MPNet
model_dir = '/media/arclabdl1/HD1/YLmiao/results/KMPnet_res/cartpole_obs_4_lr0.010000_Adagrad_step_200/'
mlp = mlp_cartpole.MLP3
cae = CAE_cartpole_voxel_2d
loss_f = nn.MSELoss()

start_epoch = 9950
direction = 0
num_steps = 200
total_input_size = 8
AE_input_size = 32
mlp_input_size = 40
output_size = 4
mpnet = KMPNet(total_input_size, AE_input_size, mlp_input_size, output_size,
               cae, mlp, loss_f)
model_path='kmpnet_epoch_%d_direction_%d_step_%d.pkl' %(start_epoch, direction, num_steps)
load_net_state(mpnet, os.path.join(model_dir, model_path))
normalize = cart_pole_obs.normalize
unnormalize = cart_pole_obs.unnormalize
# Out:
# [32, 32]
# torch.Size([1, 7, 7, 7])
# length of the output of one encoder
# 343

# %%
import time
for envi in range(len(paths)):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    #ax.set_autoscale_on(True)
    ax.set_xlim(-30, 30)
    ax.set_ylim(-np.pi, np.pi)
    new_obs_i = []
    obs_i = obs[envi]
    for k in range(len(obs_i)):
        obs_pt = []
        obs_pt.append(obs_i[k][0]-obs_width/2)
        obs_pt.append(obs_i[k][1]-obs_width/2)
        obs_pt.append(obs_i[k][0]-obs_width/2)
        obs_pt.append(obs_i[k][1]+obs_width/2)
        obs_pt.append(obs_i[k][0]+obs_width/2)
        obs_pt.append(obs_i[k][1]+obs_width/2)
        obs_pt.append(obs_i[k][0]+obs_width/2)
        obs_pt.append(obs_i[k][1]-obs_width/2)
        new_obs_i.append(obs_pt)
    obs_i = new_obs_i

    dx = 1
    dtheta = 0.1
    feasible_points = []
    infeasible_points = []
    imin = 0
    imax = int(2*30./dx)
    jmin = 0
    jmax = int(2*np.pi/dtheta)

    for i in range(imin, imax):
        for j in range(jmin, jmax):
            x = np.array([dx*i-30, 0., dtheta*j-np.pi, 0.])
            if IsInCollision(x, obs_i):
                infeasible_points.append(x)
            else:
                feasible_points.append(x)    

    feasible_points = np.array(feasible_points)
    infeasible_points = np.array(infeasible_points)
    print('feasible points')
    print(feasible_points)
    print('infeasible points')
    print(infeasible_points)
    ax.scatter(feasible_points[:,0], feasible_points[:,2], c='yellow')
    ax.scatter(infeasible_points[:,0], infeasible_points[:,2], c='pink')
    #for i in range(len(data)):
    #    update_line(hl, ax, data[i])


    
    
    #print(obs_i)
    for pathi in range(len(paths[envi])):
        start_state = sgs[envi][pathi][0]
        goal_inform_state = paths[envi][pathi][-1]
        goal_state = sgs[envi][pathi][1]
        #p = Process(target=plan_one_path, args=(obs[i], obc[i], start_state, goal_state, 500, queue))

        # propagate data
        p_start = paths[envi][pathi][0]
        detail_paths = [p_start]
        detail_controls = []
        detail_costs = []
        state = [p_start]
        control = []
        cost = []
        for k in range(len(controls[envi][pathi])):
            #state_i.append(len(detail_paths)-1)
            max_steps = int(costs[envi][pathi][k]/step_sz)
            accum_cost = 0.
            #print('p_start:')
            #print(p_start)
            #print('data:')
            #print(paths[i][j][k])
            # modify it because of small difference between data and actual propagation
            p_start = paths[envi][pathi][k]
            state[-1] = paths[envi][pathi][k]
            for step in range(1,max_steps+1):
                p_start = propagate_dynamics(p_start, controls[envi][pathi][k], step_sz)
                p_start = enforce_state_bounds(p_start)
                detail_paths.append(p_start)
                detail_controls.append(controls[envi][pathi])
                detail_costs.append(step_sz)
                accum_cost += step_sz
                if (step % 1 == 0) or (step == max_steps):
                    state.append(p_start)
                    #print('control')
                    #print(controls[i][j])
                    control.append(controls[envi][pathi][k])
                    cost.append(accum_cost)
                    accum_cost = 0.
        #print('p_start:')
        #print(p_start)
        #print('data:')
        #print(paths[i][j][-1])
        #state[-1] = paths[i][j][-1]
        data = state
        
        data = np.array(data)
        ax.scatter(data[:,0], data[:,2], c='green', s=10)
        ax.scatter(data[-1,0], data[-1,2], c='red', s=10, marker='*')
        
        start_state = data[0]
        goal_state = sgs[envi][pathi][-1]
        
        tree_nodes = [start_state.copy()]
                
        max_iter = 10
        bound_np = np.array(bound)
        sample_state = tree_nodes[0]
        num_opt_steps = 20
        num_intermediate_steps = 10
        for plan_i in range(max_iter): 
            print('iteration: ', plan_i)
            print("tree_nodes: ")
            print(tree_nodes)
            # randomly sample state in the world space
            #random_sample = np.random.uniform(low=-bound_np, high=bound_np)
            
            # find nearest neighbor in the tree
            #nearest = np.array(tree_nodes) - random_sample
            
            #print('difference:')
            #print(nearest)
            #nearest = np.linalg.norm(nearest, axis=1)
            #print("norm:")
            #print(nearest)
            #nearest = tree_nodes[np.argmin(nearest)].copy()
            #print('start point:')
            #print(nearest)
            # use MPNet to provide samples
            #nearest = tree_nodes[-1]
            bi = np.concatenate([sample_state, goal_state]).astype(np.float32)
            bi = np.array([bi])
            bi = torch.FloatTensor(bi)
            bi = normalize(bi, bound)
            bi=to_var(bi).cpu()
            bobs = np.array([obc[envi]]).astype(np.float32)
            bobs = torch.FloatTensor(bobs)
            bobs = to_var(bobs).cpu()
            #print('mpnet output: ')
            #print(mpnet(bi, bobs))
            bout = mpnet(bi, bobs)
            bout = unnormalize(bout, bound)
            
            next_state = bout.detach().data.numpy()[0]
            
            # connect from current state to next_state
            
            # initialize before solving
            x_init = np.linspace(sample_state, next_state, num_opt_steps+1)
            
            std = 0.1
            cov = np.diag([std*bound[0], std*bound[1], std*bound[2], std*bound[3]])
            #mean = next_state
            #next_state = np.random.multivariate_normal(mean=mean,cov=cov)
            mean = np.zeros(next_state.shape)
            rand_x_init = np.random.multivariate_normal(mean=mean, cov=cov, size=num_opt_steps+1)
            
            x_init = rand_x_init + x_init
            x_init[0] = sample_state
            x_init[-1] = next_state
            u_init = np.random.uniform(-300., 300., size=(num_opt_steps, 1))
            ax.scatter(x_init[:,0], x_init[:,2], c='lightgreen', s=10)
            ax.scatter(x_init[-1,0], x_init[-1,2], c='red', marker='*')
            
            
            #xs, us = bvp_solve(x_init, u_init, step_sz, num_steps)
            start_time = time.time()
            xs, us = bvp_solve_naive(x_init, u_init, step_sz, num_opt_steps, num_intermediate_steps)
            print('bvp_solver time: ', time.time() - start_time)
            #plan_one_path(obs_i, obs[i], obc[i], start_state, goal_state, goal_inform_state, 1000, data)
            #print('optimized xs:')
            #print(xs)
            #print('optimzied us:')
            #print(us)

            
            

            # propagate bvp result
            p_start = xs[0]
            detail_paths = [p_start]
            detail_controls = []
            detail_costs = []
            state = [p_start]
            control = []
            for k in range(len(us)):
                for t in range(num_intermediate_steps):
                    #state_i.append(len(detail_paths)-1)
                    # modify it because of small difference between data and actual propagation
                    p_start = propagate_dynamics(p_start, us[k], step_sz)
                    p_start = enforce_state_bounds(p_start)
                    if IsInCollision(p_start, obs_i):
                        break
                    detail_paths.append(p_start)
                    detail_controls.append(us[k])
                    state.append(p_start)
                    #print('control')
                    #print(controls[i][j])
            state = np.array(state)
            ax.scatter(state[:,0], state[:,2], c='blue', s=10)
            if len(state) > 1:
                # add results to tree
                tree_nodes.append(state[-1])
                sample_state = tree_nodes[-1]
            else:
                sample_state = tree_nodes[0]
        plt.plot()
# Out:
# /home/arclabdl1/anaconda3/envs/ylmiao_kino/lib/python3.6/site-packages/ipykernel/__main__.py:157: RuntimeWarning: divide by zero encountered in double_scalars
# /home/arclabdl1/anaconda3/envs/ylmiao_kino/lib/python3.6/site-packages/ipykernel/__main__.py:158: RuntimeWarning: divide by zero encountered in double_scalars
# feasible points
# [[-30.           0.          -3.14159265   0.        ]
#  [-30.           0.          -3.04159265   0.        ]
#  [-30.           0.          -2.94159265   0.        ]
#  ...
#  [ 29.           0.           2.75840735   0.        ]
#  [ 29.           0.           2.85840735   0.        ]
#  [ 29.           0.           2.95840735   0.        ]]
# infeasible points
# [[-15.           0.           2.15840735   0.        ]
#  [-15.           0.           2.25840735   0.        ]
#  [-15.           0.           2.35840735   0.        ]
#  ...
#  [ 20.           0.          -0.74159265   0.        ]
#  [ 20.           0.          -0.64159265   0.        ]
#  [ 20.           0.          -0.54159265   0.        ]]
# iteration:  0
# tree_nodes:
# [array([-15.17990608,   0.        ,   2.66895758,   0.        ])]
# loss:  0.27937712978373147
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937712065005105
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937712065005105
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937711151637057
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937711151637057
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793771023826902
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793771023826902
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937709324900983
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937709324900983
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793770841153294
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793770841153294
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937707498164893
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937707498164893
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793770658479685
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793770658479685
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937705671428814
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937705671428814
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793770475806078
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793770475806078
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793770384469274
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793770384469274
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793770293132471
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793770293132471
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937702017956667
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937702017956667
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793770110458864
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793770110458864
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937700191220616
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937700191220616
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793769927785259
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793769927785259
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937698364484553
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937698364484553
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793769745111653
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793769745111653
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.279376965377485
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.279376965377485
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937695624380476
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937695624380476
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793769471101245
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793769471101245
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793769379764444
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793769379764444
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937692884276416
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937692884276416
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937691970908396
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937691970908396
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793769105754037
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793769105754037
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937690144172345
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937690144172345
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937689230804347
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937689230804347
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937688317436327
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937688317436327
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793768740406831
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793768740406831
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.279376864907003
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.279376864907003
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937685577332283
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937685577332283
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937684663964274
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937684663964274
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937683750596265
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937683750596265
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937682837228267
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937682837228267
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793768192386025
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793768192386025
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937681010492244
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937681010492244
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793768009712424
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793768009712424
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793767918375625
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793767918375625
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793767827038823
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793767827038823
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793767735702024
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.2793767735702024
# tensor([6.8492e-06], dtype=torch.float64)
# loss:  0.27937676443652243
# tensor([6.8492e-06], dtype=torch.float64)
# bvp_solver time:  5.197420835494995
# iteration:  1
# tree_nodes:
# [array([-15.17990608,   0.        ,   2.66895758,   0.        ]), array([-15.46106069,  -1.25818129,   2.47952256,  -0.93635978])]
# loss:  0.0633678112763887
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336780851817016
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336780851817016
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336780575995171
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336780575995171
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336780300173335
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336780300173335
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336780024351486
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336780024351486
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336779748529639
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336779748529639
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336779472707803
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336779472707803
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336779196885961
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336779196885961
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336778921064111
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336778921064111
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336778645242272
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336778645242272
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336778369420429
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336778369420429
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.063367780935986
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.063367780935986
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336777817776755
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336777817776755
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336777541954919
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336777541954919
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336777266133067
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336777266133067
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336776990311227
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336776990311227
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.0633677671448939
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.0633677671448939
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336776438667555
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336776438667555
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.0633677616284572
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.0633677616284572
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336775887023872
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336775887023872
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336775611202028
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336775611202028
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336775335380204
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336775335380204
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336775059558361
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336775059558361
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.0633677478373651
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.0633677478373651
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336774507914682
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336774507914682
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336774232092843
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336774232092843
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336773956271004
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336773956271004
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336773680449172
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336773680449172
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336773404627338
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336773404627338
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336773128805492
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336773128805492
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.0633677285298366
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.0633677285298366
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336772577161826
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336772577161826
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.0633677230133998
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.0633677230133998
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336772025518153
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336772025518153
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336771749696309
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336771749696309
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.0633677147387448
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.0633677147387448
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336771198052649
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336771198052649
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336770922230807
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.06336770922230807
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.0633677064640898
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.0633677064640898
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.0633677037058715
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.0633677037058715
# tensor([3.8518e-06], dtype=torch.float64)
# loss:  0.0633677009476532
# tensor([3.8518e-06], dtype=torch.float64)
# bvp_solver time:  5.473865985870361
# iteration:  2
# tree_nodes:
# [array([-15.17990608,   0.        ,   2.66895758,   0.        ]), array([-15.46106069,  -1.25818129,   2.47952256,  -0.93635978]), array([-16.07049428,  -1.28734258,   1.91952128,  -1.88199088])]
# loss:  0.11213961572313672
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213961457958851
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213961457958851
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213961343604013
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213961343604013
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213961229249181
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213961229249181
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.1121396111489435
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.1121396111489435
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213961000539524
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213961000539524
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213960886184679
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213960886184679
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213960771829848
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213960771829848
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213960657475025
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213960657475025
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213960543120194
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213960543120194
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213960428765352
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213960428765352
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213960314410522
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213960314410522
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213960200055689
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213960200055689
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213960085700858
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213960085700858
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213959971346019
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213959971346019
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213959856991187
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213959856991187
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213959742636358
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213959742636358
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213959628281514
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213959628281514
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213959513926691
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213959513926691
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.1121395939957186
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.1121395939957186
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213959285217026
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213959285217026
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213959170862192
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213959170862192
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213959056507367
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213959056507367
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213958942152524
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213958942152524
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213958827797693
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213958827797693
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213958713442856
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213958713442856
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213958599088023
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213958599088023
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213958484733186
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213958484733186
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213958370378356
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213958370378356
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213958256023525
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213958256023525
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213958141668703
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213958141668703
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.1121395802731386
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.1121395802731386
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213957912959029
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213957912959029
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213957798604202
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213957798604202
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213957684249364
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213957684249364
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213957569894517
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213957569894517
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213957455539683
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213957455539683
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213957341184852
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213957341184852
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213957226830018
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213957226830018
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213957112475181
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213957112475181
# tensor([-2.5099e-06], dtype=torch.float64)
# loss:  0.11213956998120347
# tensor([-2.5099e-06], dtype=torch.float64)
# bvp_solver time:  5.884337425231934
# iteration:  3
# tree_nodes:
# [array([-15.17990608,   0.        ,   2.66895758,   0.        ]), array([-15.46106069,  -1.25818129,   2.47952256,  -0.93635978]), array([-16.07049428,  -1.28734258,   1.91952128,  -1.88199088]), array([-16.16345786,   1.0786821 ,   1.12361791,  -2.        ])]
# loss:  0.09242000456511228
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09242000403618122
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09242000403618122
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09242000350725046
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09242000350725046
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09242000297831952
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09242000297831952
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.0924200024493886
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.0924200024493886
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09242000192045782
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09242000192045782
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.0924200013915267
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.0924200013915267
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09242000086259584
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09242000086259584
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09242000033366493
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09242000033366493
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999980473402
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999980473402
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999927580319
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999927580319
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999874687212
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999874687212
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999821794146
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999821794146
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999768901049
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999768901049
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999716007951
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999716007951
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999663114873
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999663114873
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999610221781
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999610221781
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999557328703
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999557328703
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999504435577
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999504435577
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999451542506
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999451542506
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999398649414
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999398649414
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999345756322
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999345756322
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999292863234
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999292863234
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.0924199923997013
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.0924199923997013
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999187077056
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999187077056
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999134183954
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999134183954
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999081290889
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241999081290889
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.0924199902839779
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.0924199902839779
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998975504688
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998975504688
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998922611613
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998922611613
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998869718528
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998869718528
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.0924199881682542
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.0924199881682542
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998763932328
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998763932328
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998711039248
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998711039248
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998658146147
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998658146147
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998605253066
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998605253066
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.0924199855235997
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.0924199855235997
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.092419984994669
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.092419984994669
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998446573806
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998446573806
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998393680706
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998393680706
# tensor([1.4532e-06], dtype=torch.float64)
# loss:  0.09241998340787619
# tensor([1.4532e-06], dtype=torch.float64)
# bvp_solver time:  4.459300518035889
# iteration:  4
# tree_nodes:
# [array([-15.17990608,   0.        ,   2.66895758,   0.        ]), array([-15.46106069,  -1.25818129,   2.47952256,  -0.93635978]), array([-16.07049428,  -1.28734258,   1.91952128,  -1.88199088]), array([-16.16345786,   1.0786821 ,   1.12361791,  -2.        ]), array([-15.27480142,   3.81785702,   0.32593687,  -2.        ])]
# loss:  0.16165562156361768
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165561626416564
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165561626416564
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165561096471365
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165561096471365
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165560566526133
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165560566526133
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616556003658094
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616556003658094
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165559506635724
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165559506635724
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616555897669052
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616555897669052
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165558446745318
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165558446745318
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165557916800102
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165557916800102
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165557386854892
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165557386854892
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616555685690968
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616555685690968
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616555632696447
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616555632696447
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616555579701926
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616555579701926
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165555267074055
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165555267074055
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165554737128834
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165554737128834
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165554207183652
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165554207183652
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165553677238437
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165553677238437
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616555314729322
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616555314729322
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165552617348034
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165552617348034
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165552087402837
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165552087402837
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165551557457622
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165551557457622
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165551027512415
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165551027512415
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165550497567224
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165550497567224
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165549967622
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165549967622
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165549437676807
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165549437676807
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616554890773161
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616554890773161
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616554837778642
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616554837778642
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616554784784121
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616554784784121
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165547317895998
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165547317895998
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165546787950807
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165546787950807
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165546258005606
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165546258005606
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.161655457280604
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.161655457280604
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165545198115208
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165545198115208
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165544668170015
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165544668170015
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165544138224802
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165544138224802
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165543608279612
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165543608279612
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165543078334427
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165543078334427
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165542548389206
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165542548389206
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165542018444018
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165542018444018
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616554148849883
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.1616554148849883
# tensor([4.9776e-06], dtype=torch.float64)
# loss:  0.16165540958553642
# tensor([4.9776e-06], dtype=torch.float64)
# bvp_solver time:  5.895230531692505
# iteration:  5
# tree_nodes:
# [array([-15.17990608,   0.        ,   2.66895758,   0.        ]), array([-15.46106069,  -1.25818129,   2.47952256,  -0.93635978]), array([-16.07049428,  -1.28734258,   1.91952128,  -1.88199088]), array([-16.16345786,   1.0786821 ,   1.12361791,  -2.        ]), array([-15.27480142,   3.81785702,   0.32593687,  -2.        ]), array([-13.41479407,   4.5855647 ,  -0.43044805,  -1.68748803])]
# loss:  0.13807937629045208
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807937226790135
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807937226790135
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807936824535058
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807936824535058
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807936422279982
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807936422279982
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807936020024897
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807936020024897
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380793561776983
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380793561776983
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807935215514736
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807935215514736
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380793481325967
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380793481325967
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380793441100459
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380793441100459
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807934008749517
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807934008749517
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807933606494438
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807933606494438
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807933204239356
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807933204239356
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807932801984277
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807932801984277
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807932399729192
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807932399729192
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380793199747411
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380793199747411
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380793159521903
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380793159521903
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807931192963951
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807931192963951
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807930790708872
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807930790708872
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807930388453782
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807930388453782
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807929986198697
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807929986198697
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380792958394362
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380792958394362
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807929181688525
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807929181688525
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807928779433448
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807928779433448
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380792837717837
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380792837717837
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380792797492328
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380792797492328
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807927572668188
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807927572668188
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380792717041311
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380792717041311
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807926768158021
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807926768158021
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807926365902926
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807926365902926
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807925963647844
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807925963647844
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807925561392753
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807925561392753
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807925159137666
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807925159137666
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807924756882567
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807924756882567
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807924354627482
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807924354627482
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807923952372397
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807923952372397
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807923550117307
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807923550117307
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807923147862206
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807923147862206
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380792274560712
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.1380792274560712
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807922343352028
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807922343352028
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807921941096946
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807921941096946
# tensor([4.4715e-06], dtype=torch.float64)
# loss:  0.13807921538841858
# tensor([4.4715e-06], dtype=torch.float64)
# bvp_solver time:  4.73891019821167
# iteration:  6
# tree_nodes:
# [array([-15.17990608,   0.        ,   2.66895758,   0.        ]), array([-15.46106069,  -1.25818129,   2.47952256,  -0.93635978]), array([-16.07049428,  -1.28734258,   1.91952128,  -1.88199088]), array([-16.16345786,   1.0786821 ,   1.12361791,  -2.        ]), array([-15.27480142,   3.81785702,   0.32593687,  -2.        ]), array([-13.41479407,   4.5855647 ,  -0.43044805,  -1.68748803]), array([-11.4223109 ,   4.08417611,  -1.01166764,  -0.85581169])]
# loss:  0.183211754580087
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321175195383674
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321175195383674
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321174932758633
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321174932758633
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321174670133608
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321174670133608
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321174407508573
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321174407508573
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321174144883534
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321174144883534
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321173882258507
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321173882258507
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321173619633466
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321173619633466
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.1832117335700843
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.1832117335700843
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321173094383403
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321173094383403
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321172831758362
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321172831758362
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321172569133326
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321172569133326
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321172306508296
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321172306508296
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321172043883263
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321172043883263
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321171781258228
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321171781258228
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321171518633195
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321171518633195
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321171256008156
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321171256008156
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321170993383118
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321170993383118
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.1832117073075808
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.1832117073075808
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.1832117046813304
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.1832117046813304
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321170205508008
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321170205508008
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.1832116994288297
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.1832116994288297
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321169680257937
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321169680257937
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321169417632902
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321169417632902
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321169155007858
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321169155007858
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321168892382825
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321168892382825
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.1832116862975779
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.1832116862975779
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321168367132745
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321168367132745
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321168104507715
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321168104507715
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321167841882682
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321167841882682
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321167579257636
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321167579257636
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321167316632597
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321167316632597
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321167054007564
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321167054007564
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.1832116679138252
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.1832116679138252
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321166528757482
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321166528757482
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321166266132444
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321166266132444
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.1832116600350741
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.1832116600350741
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321165740882367
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321165740882367
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321165478257329
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321165478257329
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321165215632287
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321165215632287
# tensor([3.6348e-06], dtype=torch.float64)
# loss:  0.18321164953007246
# tensor([3.6348e-06], dtype=torch.float64)
# bvp_solver time:  6.2437450885772705
# iteration:  7
# tree_nodes:
# [array([-15.17990608,   0.        ,   2.66895758,   0.        ]), array([-15.46106069,  -1.25818129,   2.47952256,  -0.93635978]), array([-16.07049428,  -1.28734258,   1.91952128,  -1.88199088]), array([-16.16345786,   1.0786821 ,   1.12361791,  -2.        ]), array([-15.27480142,   3.81785702,   0.32593687,  -2.        ]), array([-13.41479407,   4.5855647 ,  -0.43044805,  -1.68748803]), array([-11.4223109 ,   4.08417611,  -1.01166764,  -0.85581169]), array([-9.83308499,  4.01705826, -1.13789045,  0.21886487])]
# loss:  0.2688824761063828
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824741557523
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824741557523
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824722051216
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824722051216
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824702544911
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824702544911
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824683038604
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824683038604
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824663532299
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824663532299
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824644025993
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824644025993
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824624519688
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824624519688
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824605013381
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824605013381
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824585507075
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824585507075
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824566000769
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824566000769
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824546494463
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824546494463
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824526988157
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824526988157
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824507481851
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824507481851
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824487975545
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824487975545
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888244684692403
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888244684692403
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888244489629337
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888244489629337
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888244294566277
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888244294566277
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888244099503217
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888244099503217
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888243904440157
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888243904440157
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.268882437093771
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.268882437093771
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824351431404
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824351431404
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824331925098
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824331925098
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888243124187916
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888243124187916
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824292912485
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824292912485
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888242734061796
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888242734061796
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888242538998736
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888242538998736
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888242343935675
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888242343935675
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824214887262
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824214887262
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824195380955
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824195380955
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.268882417587465
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.268882417587465
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824156368343
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824156368343
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888241368620364
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888241368620364
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888241173557303
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888241173557303
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824097849425
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824097849425
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824078343119
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824078343119
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888240588368123
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888240588368123
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888240393305063
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888240393305063
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888240198242
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888240198242
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824000317894
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.2688824000317894
# tensor([3.1066e-06], dtype=torch.float64)
# loss:  0.26888239808115877
# tensor([3.1066e-06], dtype=torch.float64)
# bvp_solver time:  4.17013955116272
# iteration:  8
# tree_nodes:
# [array([-15.17990608,   0.        ,   2.66895758,   0.        ]), array([-15.46106069,  -1.25818129,   2.47952256,  -0.93635978]), array([-16.07049428,  -1.28734258,   1.91952128,  -1.88199088]), array([-16.16345786,   1.0786821 ,   1.12361791,  -2.        ]), array([-15.27480142,   3.81785702,   0.32593687,  -2.        ]), array([-13.41479407,   4.5855647 ,  -0.43044805,  -1.68748803]), array([-11.4223109 ,   4.08417611,  -1.01166764,  -0.85581169]), array([-9.83308499,  4.01705826, -1.13789045,  0.21886487]), array([-8.90459936,  4.78697794, -1.04729022,  0.66492999])]
# loss:  0.205465295683454
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054652929753712
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054652929753712
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546529026728833
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546529026728833
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546528755920557
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546528755920557
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546528485112275
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546528485112275
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546528214303994
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546528214303994
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546527943495713
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546527943495713
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054652767268743
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054652767268743
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546527401879144
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546527401879144
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546527131070863
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546527131070863
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054652686026258
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054652686026258
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546526589454298
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546526589454298
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054652631864602
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054652631864602
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546526047837732
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546526047837732
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546525777029448
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546525777029448
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546525506221164
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546525506221164
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546525235412874
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546525235412874
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546524964604593
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546524964604593
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546524693796311
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546524693796311
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546524422988022
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546524422988022
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546524152179746
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546524152179746
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054652388137145
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054652388137145
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546523610563167
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546523610563167
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054652333975489
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054652333975489
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.205465230689466
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.205465230689466
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054652279813832
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054652279813832
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546522527330027
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546522527330027
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546522256521743
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546522256521743
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546521985713462
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546521985713462
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546521714905175
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546521714905175
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546521444096888
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546521444096888
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.205465211732886
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.205465211732886
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546520902480314
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546520902480314
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054652063167203
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054652063167203
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054652036086374
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054652036086374
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546520090055448
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546520090055448
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546519819247167
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546519819247167
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054651954843887
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.2054651954843887
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546519277630593
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546519277630593
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.205465190068223
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.205465190068223
# tensor([3.6316e-06], dtype=torch.float64)
# loss:  0.20546518736014013
# tensor([3.6316e-06], dtype=torch.float64)
# bvp_solver time:  5.900718927383423
# iteration:  9
# tree_nodes:
# [array([-15.17990608,   0.        ,   2.66895758,   0.        ]), array([-15.46106069,  -1.25818129,   2.47952256,  -0.93635978]), array([-16.07049428,  -1.28734258,   1.91952128,  -1.88199088]), array([-16.16345786,   1.0786821 ,   1.12361791,  -2.        ]), array([-15.27480142,   3.81785702,   0.32593687,  -2.        ]), array([-13.41479407,   4.5855647 ,  -0.43044805,  -1.68748803]), array([-11.4223109 ,   4.08417611,  -1.01166764,  -0.85581169]), array([-9.83308499,  4.01705826, -1.13789045,  0.21886487]), array([-8.90459936,  4.78697794, -1.04729022,  0.66492999])]
# loss:  0.2730087929649502
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.27300878382561355
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.27300878382561355
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.2730087746862767
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.2730087746862767
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.27300876554694
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.27300876554694
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.27300875640760347
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.27300875640760347
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.2730087472682668
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.2730087472682668
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.27300873812893023
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.27300873812893023
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.2730087289895936
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.2730087289895936
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.2730087198502569
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.2730087198502569
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.27300871071092025
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.27300871071092025
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.2730087015715838
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.2730087015715838
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.2730086924322471
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.2730086924322471
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.2730086832929105
# tensor([6.8523e-06], dtype=torch.float64)
# loss:  0.2730086832929105
# tensor([6.8523e-06], dtype=torch.float64)
