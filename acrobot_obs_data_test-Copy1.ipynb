# %%
from ctypes import *
#ctypes.cdll.LoadLibrary('')
#lib1 = CDLL("deps/sparse_rrt/deps/trajopt/build/lib/libsco.so")
#lib2 = CDLL("deps/sparse_rrt/deps/trajopt/build/lib/libutils.so")

import sys
sys.path.append('deps/sparse_rrt')
sys.path.append('.')

from sparse_rrt.planners import SST
#from env.cartpole_obs import CartPoleObs
#from env.cartpole import CartPole
from sparse_rrt.systems.acrobot import Acrobot
from sparse_rrt.systems import standard_cpp_systems
from sparse_rrt import _sst_module
import numpy as np
import time
from tools.pcd_generation import rectangle_pcd
from plan_utility.line_line_cc import *
import pickle
obs_list = []
LENGTH = 20.
width = 6.
near = width * 1.2
# convert from obs to point cloud
# load generated point cloud
obs_list_total = []
obc_list_total = []
for i in range(2):
    file = open('data/acrobot_simple/obs_%d.pkl' % (i), 'rb')
    obs_list_total.append(pickle.load(file))
    file = open('data/acrobot_simple/obc_%d.pkl' % (i), 'rb')
    obc_list_total.append(pickle.load(file))

obs_idx = 1
p_idx =4
# Create custom system
#obs_list = [[-10., -3.],
#            [0., 3.],
#            [10, -3.]]
obs_list_total[1][0][0] += 3.
obs_list_total[1][0][1] -= 3.

obs_list_total = np.array(obs_list_total)
obc_list_total = np.array(obc_list_total)
obs_list = obs_list_total[obs_idx]
obc_list = obc_list_total[obs_idx]
print('generated.')
print(obs_list.shape)
# Out:
# generated.
# (2, 2)

# %%
# load path
path = open('../CSE203B_trajopt/trajopt_path_lr_0.010000_RMSprop.pkl','rb')
path = pickle.load(path)
controls = open('../CSE203B_trajopt/trajopt_control_lr_0.010000_RMSprop.pkl', 'rb')
controls = pickle.load(controls)
init_path = open('../CSE203B_trajopt/trajopt_init_path.pkl','rb')
init_path = pickle.load(init_path)
init_controls = open('../CSE203B_trajopt/trajopt_init_control.pkl', 'rb')
init_controls = pickle.load(init_controls)
init_path = init_path[30:60]

stat = open('../CSE203B_trajopt/trajopt_stat_lr_0.010000_RMSprop.pkl','rb')
stat = pickle.load(stat)
print(stat)
#path = open('data/acrobot_simple/%d/path_%d.pkl' % (obs_idx, p_idx), 'rb')
#path = pickle.load(path)
#controls = open('data/acrobot_simple/%d/control_%d.pkl' % (obs_idx, p_idx), 'rb')
#controls = pickle.load(controls)

#costs = open('data/acrobot_simple/%d/cost_%d.pkl' % (obs_idx, p_idx), 'rb')
#costs = pickle.load(costs)
# Out:
# [2.217883484447492, 0.5598401518717567, 0.20524330886254888]

# %%
print('path:')
print(path)
print('control:')
print(controls)
print(len(path))
print('init_path')
print(init_path)
print(((path[-1][:2] - init_path[-1][:2])**2).sum())
#print('costs')
#print(costs)
##path = path[30:60]
##controls = controls[30:60]
#costs = costs#[6:]
# Out:
# path:
# [array([-0.35341975, -2.30131878,  4.53975847, -5.87144004]), array([-0.11179283, -1.98315745,  5.18938112, -7.3372017 ]), array([-0.05070995, -2.17323859,  4.62189421, -5.79537875]), array([ 0.12364471, -2.18178419,  1.5941838 ,  1.09830842]), array([ 0.20021316, -2.09127507, -0.60845488,  5.91700371]), array([ 0.20621193, -1.93490075, -2.02265371,  8.76853027]), array([ 0.16714342, -1.73300544, -2.61007463,  9.66890402]), array([ 0.10382232, -1.52822375, -2.19284094,  8.38028111]), array([ 0.03533818, -1.35677093, -0.92300278,  5.36556902]), array([-0.02009031, -1.25291057,  1.12762046,  0.82122229]), array([-0.03900059, -1.25695465,  3.83008636, -4.9873762 ]), array([ -0.02560168,  -1.37641625,   6.99466878, -11.6618561 ]), array([  0.05188272,  -1.65834805,  10.28349017, -18.52663308]), array([  0.17252129,  -2.08066856,  13.47923264, -25.12300458]), array([  0.33519511,  -2.66907827,  16.33875887, -31.02952676]), array([  0.40562039,  -3.52828792,  15.95767693, -29.9746332 ]), array([  0.4290676 ,  -4.37239579,  14.280235  , -26.64841493]), array([  0.61443472,  -4.98030774,  12.03338704, -22.38540773]), array([  0.77346244,  -5.45997096,  10.15370532, -18.79766328]), array([  0.92673953,  -5.86428099,   8.11659488, -14.78710397]), array([  1.04321424,  -6.16573047,   5.93865082, -10.39974297]), array([ 1.14479795, -6.37953565,  3.79608274, -6.06360587]), array([ 1.20407152, -6.49536719,  1.84274937, -2.10228541]), array([ 1.25717528, -6.52460015,  0.12247702,  1.34934836]), array([ 1.27527499, -6.48116535, -1.33749621,  4.26164484]), array([ 1.29826975, -6.37367352, -2.72046596,  6.97398055]), array([ 1.30118232, -6.19662179, -3.99222232,  9.48238815]), array([ 1.30620122, -5.97061961, -4.98662085, 11.37791822]), array([ 1.31962949, -5.67815424, -5.58158767, 12.47153857]), array([ 1.35430447, -5.35017443, -5.22333774, 11.53451197])]
# control:
# [array([-0.9417979]), array([49.10736831]), array([272.61370984]), array([191.11510449]), array([104.89820991]), array([20.74284053]), array([-61.26904072]), array([-111.66495802]), array([-146.99159852]), array([-175.73240365]), array([-204.49378686]), array([-235.90182602]), array([-277.06130836]), array([-310.84471525]), array([-16.70690771]), array([187.00156875]), array([241.16662908]), array([166.04232569]), array([128.45460871]), array([103.97804472]), array([88.32948007]), array([78.50996258]), array([68.83295034]), array([58.11584646]), array([53.38129544]), array([49.10407418]), array([37.85434718]), array([26.12155037]), array([-13.73639058])]
# 30
# init_path
# [[-0.35341975 -2.30131878  4.53975847 -5.87144004]
#  [-0.26262458 -2.41874758  4.64115216 -5.7919258 ]
#  [-0.16980154 -2.5345861   4.73031167 -5.71129037]
#  [-0.0751953  -2.6488119   4.80281008 -5.63056394]
#  [ 0.0208609  -2.76142318  4.85428252 -5.55082922]
#  [ 0.11794655 -2.87243977  4.88083126 -5.4731153 ]
#  [ 0.21556317 -2.98190207  4.87942984 -5.39826143]
#  [ 0.31315177 -3.0898673   4.84825785 -5.32678028]
#  [ 0.41011693 -3.19640291  4.7869044  -5.25875458]
#  [ 0.50585501 -3.301578    4.69640261 -5.19379499]
#  [ 0.59978307 -3.4054539   4.57909238 -5.13107149]
#  [ 0.69136491 -3.50807533  4.43834228 -5.06941134]
#  [ 0.78013176 -3.60946356  4.27818509 -5.00744017]
#  [ 0.86569546 -3.70961236  4.10292954 -4.94373478]
#  [ 0.94775405 -3.80848705  3.91680495 -4.87695849]
#  [ 1.02609015 -3.90602622  3.72367903 -4.80595922]
#  [ 1.10056373 -4.00214541  3.52686884 -4.72982323]
#  [ 1.17110111 -4.09674187  3.32904565 -4.64788821]
#  [ 1.23768202 -4.18969964  3.13222015 -4.55972635]
#  [ 1.30032642 -4.28089416  2.93778721 -4.46510993]
#  [ 1.35908217 -4.37019636  2.74660753 -4.36397113]
#  [ 1.41401432 -4.45747579  2.55910654 -4.25636402]
#  [ 1.46519645 -4.54260307  2.37537555 -4.14243375]
#  [ 1.51270396 -4.62545174  2.19526561 -4.0223944 ]
#  [ 1.55660927 -4.70589963  2.01846869 -3.89651526]
#  [ 1.59697865 -4.78382993  1.84458429 -3.76511371]
#  [ 1.63387033 -4.85913221  1.67317155 -3.62855255]
#  [ 1.66733376 -4.93170326  1.5037882  -3.4872396 ]
#  [ 1.69740953 -5.00144805  1.33601787 -3.34162741]
#  [ 1.72412989 -5.0682806   1.16948791 -3.19221172]]
# 0.2162349685258069

# %%
# visualize the path

from numpy import sin, cos
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate
import matplotlib.animation as animation
import matplotlib as mpl
import matplotlib.patches as patches
from IPython.display import HTML
from visual.visualizer import Visualizer



class AcrobotVisualizer(Visualizer):
    def __init__(self, system, params):
        super(AcrobotVisualizer, self).__init__(system, params)
        self.dt = 0.05

    def _state_to_xy(self, state):
        angle0 = state[0]
        angle1 = state[1]
        x0 = 0.
        y0 = 0.
        x1 = LENGTH * np.cos(angle0 - np.pi/2)
        y1 = LENGTH * np.sin(angle0 - np.pi/2)
        x2 = x1 + LENGTH * np.cos(angle0 + angle1 - np.pi/2)
        y2 = y1 + LENGTH * np.sin(angle0 + angle1 - np.pi/2)
        return x0, y0, x1, y1, x2, y2
    def _init(self):
        # clear the current ax
        ax = plt.gca()
        ax.clear()
        # add patches
        state = self.states[0]
        print('state:')
        print(state)
        x0, y0, x1, y1, x2, y2 = self._state_to_xy(state)
        print('x1: %f, y1: %f, x2: %f, y2: %f' % (x1, y1, x2, y2))
        self.l1 = ax.plot([x0,x1,x2], [y0,y1,y2])[0]
        self.recs = []
        for i in range(len(self.obs)):
            x, y = self.obs[i]
            obs = patches.Rectangle((x-self.params['obs_w']/2,y-params['obs_h']/2),\
                                       self.params['obs_w'],self.params['obs_h'],\
                                      linewidth=.5,edgecolor='black',facecolor='black')
            self.recs.append(obs)
            ax.add_patch(obs)
        self.recs.append(self.l1)
        return self.recs
    def _animate(self, i):
        ax = plt.gca()
        ax.set_xlim(-40, 40)
        ax.set_ylim(-40, 40)
        state = self.states[i]
        x0, y0, x1, y1, x2, y2 = self._state_to_xy(state)
        self.l1.set_xdata([x0,x1,x2])
        self.l1.set_ydata([y0,y1,y2])
        return self.recs


 
    def animate(self, states, actions, obstacles):
        '''
        given a list of states, actions and obstacles, animate the robot
        '''
        # transform the waypoint states and actions into trajectory
        traj = []
        for i in range(len(states)):
            print('state: %d, remaining: %d' % (i, len(states)-i))
            s = states[i]
            traj.append(s)
            print(s)
        traj = np.array(traj)
        print(traj)
        print("animating...")
        # animate
        self.states = traj
        self.obs = obstacles
        print(len(self.states))
        ani = animation.FuncAnimation(plt.gcf(), self._animate, range(0, len(self.states)),
                                      interval=self.dt*5000, blit=True, init_func=self._init,
                                      repeat=True)
        return ani

# %%
"""
# visualize the path

from numpy import sin, cos
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate
import matplotlib.animation as animation
import matplotlib as mpl
import matplotlib.patches as patches
from IPython.display import HTML
from visual.visualizer import Visualizer



class AcrobotVisualizer(Visualizer):
    def __init__(self, system, params):
        super(AcrobotVisualizer, self).__init__(system, params)
        self.dt = 0.05

    def _state_to_xy(self, state):
        angle0 = state[0]
        angle1 = state[1]
        x0 = 0.
        y0 = 0.
        x1 = LENGTH * np.cos(angle0 - np.pi/2)
        y1 = LENGTH * np.sin(angle0 - np.pi/2)
        x2 = x1 + LENGTH * np.cos(angle0 + angle1 - np.pi/2)
        y2 = y1 + LENGTH * np.sin(angle0 + angle1 - np.pi/2)
        return x0, y0, x1, y1, x2, y2
    def _init(self):
        # clear the current ax
        ax = plt.gca()
        ax.clear()
        # add patches
        state = self.states[0]
        print('state:')
        print(state)
        x0, y0, x1, y1, x2, y2 = self._state_to_xy(state)
        print('x1: %f, y1: %f, x2: %f, y2: %f' % (x1, y1, x2, y2))
        self.l1 = ax.plot([x0,x1,x2], [y0,y1,y2])[0]
        self.recs = []
        for i in range(len(self.obs)):
            x, y = self.obs[i]
            obs = patches.Rectangle((x-self.params['obs_w']/2,y-params['obs_h']/2),\
                                       self.params['obs_w'],self.params['obs_h'],\
                                      linewidth=.5,edgecolor='black',facecolor='black')
            self.recs.append(obs)
            ax.add_patch(obs)
        self.recs.append(self.l1)
        return self.recs
    def _animate(self, i):
        ax = plt.gca()
        ax.set_xlim(-40, 40)
        ax.set_ylim(-40, 40)
        state = self.states[i]
        x0, y0, x1, y1, x2, y2 = self._state_to_xy(state)
        self.l1.set_xdata([x0,x1,x2])
        self.l1.set_ydata([y0,y1,y2])
        return self.recs


 
    def animate(self, states, actions, obstacles):
        '''
        given a list of states, actions and obstacles, animate the robot
        '''
        # transform the waypoint states and actions into trajectory
        traj = []
        for i in range(len(states)-1):
            print('state: %d, remaining: %d' % (i, len(states)-i))
            s = states[i]
            print(s)
            action = actions[i]
            sT = states[i+1]
            # propogate until reaching next state
            while True:
                traj.append(np.array(s))
                #print("porpagating...")
                #print(s)
                #print('st:')
                #print(sT)
                #print('distance:')
                #print(np.linalg.norm(s-sT))
                s = self.system.propagate(s, action, 1, self.params['integration_step'])
                if np.linalg.norm(s-sT) <= 0.1:
                    break
        traj = np.array(traj)
        print(traj)
        print("animating...")
        # animate
        self.states = traj
        self.obs = obstacles
        print(len(self.states))
        ani = animation.FuncAnimation(plt.gcf(), self._animate, range(0, len(self.states)),
                                      interval=self.dt*500, blit=True, init_func=self._init,
                                      repeat=True)
        return ani
"""
# Out:
# '\n# visualize the path\n\nfrom numpy import sin, cos\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport scipy.integrate as integrate\nimport matplotlib.animation as animation\nimport matplotlib as mpl\nimport matplotlib.patches as patches\nfrom IPython.display import HTML\nfrom visual.visualizer import Visualizer\n\n\n\nclass AcrobotVisualizer(Visualizer):\n    def __init__(self, system, params):\n        super(AcrobotVisualizer, self).__init__(system, params)\n        self.dt = 0.05\n\n    def _state_to_xy(self, state):\n        angle0 = state[0]\n        angle1 = state[1]\n        x0 = 0.\n        y0 = 0.\n        x1 = LENGTH * np.cos(angle0 - np.pi/2)\n        y1 = LENGTH * np.sin(angle0 - np.pi/2)\n        x2 = x1 + LENGTH * np.cos(angle0 + angle1 - np.pi/2)\n        y2 = y1 + LENGTH * np.sin(angle0 + angle1 - np.pi/2)\n        return x0, y0, x1, y1, x2, y2\n    def _init(self):\n        # clear the current ax\n        ax = plt.gca()\n        ax.clear()\n        # add patches\n        state = self.states[0]\n        print(\'state:\')\n        print(state)\n        x0, y0, x1, y1, x2, y2 = self._state_to_xy(state)\n        print(\'x1: %f, y1: %f, x2: %f, y2: %f\' % (x1, y1, x2, y2))\n        self.l1 = ax.plot([x0,x1,x2], [y0,y1,y2])[0]\n        self.recs = []\n        for i in range(len(self.obs)):\n            x, y = self.obs[i]\n            obs = patches.Rectangle((x-self.params[\'obs_w\']/2,y-params[\'obs_h\']/2),                                       self.params[\'obs_w\'],self.params[\'obs_h\'],                                      linewidth=.5,edgecolor=\'black\',facecolor=\'black\')\n            self.recs.append(obs)\n            ax.add_patch(obs)\n        self.recs.append(self.l1)\n        return self.recs\n    def _animate(self, i):\n        ax = plt.gca()\n        ax.set_xlim(-40, 40)\n        ax.set_ylim(-40, 40)\n        state = self.states[i]\n        x0, y0, x1, y1, x2, y2 = self._state_to_xy(state)\n        self.l1.set_xdata([x0,x1,x2])\n        self.l1.set_ydata([y0,y1,y2])\n        return self.recs\n\n\n \n    def animate(self, states, actions, obstacles):\n        \'\'\'\n        given a list of states, actions and obstacles, animate the robot\n        \'\'\'\n        # transform the waypoint states and actions into trajectory\n        traj = []\n        for i in range(len(states)-1):\n            print(\'state: %d, remaining: %d\' % (i, len(states)-i))\n            s = states[i]\n            print(s)\n            action = actions[i]\n            sT = states[i+1]\n            # propogate until reaching next state\n            while True:\n                traj.append(np.array(s))\n                #print("porpagating...")\n                #print(s)\n                #print(\'st:\')\n                #print(sT)\n                #print(\'distance:\')\n                #print(np.linalg.norm(s-sT))\n                s = self.system.propagate(s, action, 1, self.params[\'integration_step\'])\n                if np.linalg.norm(s-sT) <= 0.1:\n                    break\n        traj = np.array(traj)\n        print(traj)\n        print("animating...")\n        # animate\n        self.states = traj\n        self.obs = obstacles\n        print(len(self.states))\n        ani = animation.FuncAnimation(plt.gcf(), self._animate, range(0, len(self.states)),\n                                      interval=self.dt*500, blit=True, init_func=self._init,\n                                      repeat=True)\n        return ani\n'

# %%
# visualize the path

from numpy import sin, cos
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate
import matplotlib.animation as animation
import matplotlib as mpl
import matplotlib.patches as patches
from IPython.display import HTML
from visual.visualizer import Visualizer



class AcrobotPlotter(Visualizer):
    def __init__(self, system, params):
        super(AcrobotPlotter, self).__init__(system, params)
        self.dt = 0.05

    def _state_to_xy(self, state):
        angle0 = state[0]
        angle1 = state[1]
        x0 = 0.
        y0 = 0.
        x1 = LENGTH * np.cos(angle0 - np.pi/2)
        y1 = LENGTH * np.sin(angle0 - np.pi/2)
        x2 = x1 + LENGTH * np.cos(angle0 + angle1 - np.pi/2)
        y2 = y1 + LENGTH * np.sin(angle0 + angle1 - np.pi/2)
        return x0, y0, x1, y1, x2, y2
    def _init(self):
        # clear the current ax
        ax = plt.gca()
        ax.clear()
        # add patches
        state = self.states[0]
        print('state:')
        print(state)
        x0, y0, x1, y1, x2, y2 = self._state_to_xy(state)
        print('x1: %f, y1: %f, x2: %f, y2: %f' % (x1, y1, x2, y2))
        self.l1 = ax.plot([x0,x1,x2], [y0,y1,y2])[0]
        self.recs = []
        for i in range(len(self.obs)):
            x, y = self.obs[i]
            obs = patches.Rectangle((x-self.params['obs_w']/2,y-params['obs_h']/2),\
                                       self.params['obs_w'],self.params['obs_h'],\
                                      linewidth=.5,edgecolor='black',facecolor='black')
            self.recs.append(obs)
            ax.add_patch(obs)
        self.recs.append(self.l1)
        return self.recs
    def _animate(self, i):
        ax = plt.gca()
        ax.set_xlim(-40, 40)
        ax.set_ylim(-40, 40)
        state = self.states[i]
        x0, y0, x1, y1, x2, y2 = self._state_to_xy(state)
        self.l1.set_xdata([x0,x1,x2])
        self.l1.set_ydata([y0,y1,y2])
        return self.recs


    def animate(self, states, actions, obstacles):
        '''
        given a list of states, actions and obstacles, animate the robot
        '''
        # transform the waypoint states and actions into trajectory
        traj = []
        for i in range(len(states)):
            print('state: %d, remaining: %d' % (i, len(states)-i))
            s = states[i]
            traj.append(s)
            print(s)
        traj = np.array(traj)
        print(traj)
        print("animating...")
        # animate
        self.states = traj
        self.obs = obstacles
        print(len(self.states))
        
        self._init()
        for i in range(len(traj)):
            x0, y0, x1, y1, x2, y2 = self._state_to_xy(traj[i])
            ax = plt.gca()
            ax.set_xlim(-40, 40)
            ax.set_ylim(-40, 40)
            if i == 0:
                ax.plot([x0,x1,x2],[y0,y1,y2],alpha=1, c='red')
            else:
                ax.plot([x0,x1,x2],[y0,y1,y2],alpha=float(i)/len(traj), c='blue')

# %%
params = {}
params['obs_w'] = width
params['obs_h'] = width
params['integration_step'] = 0.02
system = Acrobot()
vis = AcrobotPlotter(system, params)
states = path
actions = controls
print('states:')
print(states)
vis.animate(np.array(states), np.array(actions), obs_list)

#anim.save('acrobot_env%d_path%d.mp4' % (obs_idx, p_idx))
# Out:
# states:
# [array([-0.35341975, -2.30131878,  4.53975847, -5.87144004]), array([-0.11179283, -1.98315745,  5.18938112, -7.3372017 ]), array([-0.05070995, -2.17323859,  4.62189421, -5.79537875]), array([ 0.12364471, -2.18178419,  1.5941838 ,  1.09830842]), array([ 0.20021316, -2.09127507, -0.60845488,  5.91700371]), array([ 0.20621193, -1.93490075, -2.02265371,  8.76853027]), array([ 0.16714342, -1.73300544, -2.61007463,  9.66890402]), array([ 0.10382232, -1.52822375, -2.19284094,  8.38028111]), array([ 0.03533818, -1.35677093, -0.92300278,  5.36556902]), array([-0.02009031, -1.25291057,  1.12762046,  0.82122229]), array([-0.03900059, -1.25695465,  3.83008636, -4.9873762 ]), array([ -0.02560168,  -1.37641625,   6.99466878, -11.6618561 ]), array([  0.05188272,  -1.65834805,  10.28349017, -18.52663308]), array([  0.17252129,  -2.08066856,  13.47923264, -25.12300458]), array([  0.33519511,  -2.66907827,  16.33875887, -31.02952676]), array([  0.40562039,  -3.52828792,  15.95767693, -29.9746332 ]), array([  0.4290676 ,  -4.37239579,  14.280235  , -26.64841493]), array([  0.61443472,  -4.98030774,  12.03338704, -22.38540773]), array([  0.77346244,  -5.45997096,  10.15370532, -18.79766328]), array([  0.92673953,  -5.86428099,   8.11659488, -14.78710397]), array([  1.04321424,  -6.16573047,   5.93865082, -10.39974297]), array([ 1.14479795, -6.37953565,  3.79608274, -6.06360587]), array([ 1.20407152, -6.49536719,  1.84274937, -2.10228541]), array([ 1.25717528, -6.52460015,  0.12247702,  1.34934836]), array([ 1.27527499, -6.48116535, -1.33749621,  4.26164484]), array([ 1.29826975, -6.37367352, -2.72046596,  6.97398055]), array([ 1.30118232, -6.19662179, -3.99222232,  9.48238815]), array([ 1.30620122, -5.97061961, -4.98662085, 11.37791822]), array([ 1.31962949, -5.67815424, -5.58158767, 12.47153857]), array([ 1.35430447, -5.35017443, -5.22333774, 11.53451197])]
# state: 0, remaining: 30
# [-0.35341975 -2.30131878  4.53975847 -5.87144004]
# state: 1, remaining: 29
# [-0.11179283 -1.98315745  5.18938112 -7.3372017 ]
# state: 2, remaining: 28
# [-0.05070995 -2.17323859  4.62189421 -5.79537875]
# state: 3, remaining: 27
# [ 0.12364471 -2.18178419  1.5941838   1.09830842]
# state: 4, remaining: 26
# [ 0.20021316 -2.09127507 -0.60845488  5.91700371]
# state: 5, remaining: 25
# [ 0.20621193 -1.93490075 -2.02265371  8.76853027]
# state: 6, remaining: 24
# [ 0.16714342 -1.73300544 -2.61007463  9.66890402]
# state: 7, remaining: 23
# [ 0.10382232 -1.52822375 -2.19284094  8.38028111]
# state: 8, remaining: 22
# [ 0.03533818 -1.35677093 -0.92300278  5.36556902]
# state: 9, remaining: 21
# [-0.02009031 -1.25291057  1.12762046  0.82122229]
# state: 10, remaining: 20
# [-0.03900059 -1.25695465  3.83008636 -4.9873762 ]
# state: 11, remaining: 19
# [ -0.02560168  -1.37641625   6.99466878 -11.6618561 ]
# state: 12, remaining: 18
# [  0.05188272  -1.65834805  10.28349017 -18.52663308]
# state: 13, remaining: 17
# [  0.17252129  -2.08066856  13.47923264 -25.12300458]
# state: 14, remaining: 16
# [  0.33519511  -2.66907827  16.33875887 -31.02952676]
# state: 15, remaining: 15
# [  0.40562039  -3.52828792  15.95767693 -29.9746332 ]
# state: 16, remaining: 14
# [  0.4290676   -4.37239579  14.280235   -26.64841493]
# state: 17, remaining: 13
# [  0.61443472  -4.98030774  12.03338704 -22.38540773]
# state: 18, remaining: 12
# [  0.77346244  -5.45997096  10.15370532 -18.79766328]
# state: 19, remaining: 11
# [  0.92673953  -5.86428099   8.11659488 -14.78710397]
# state: 20, remaining: 10
# [  1.04321424  -6.16573047   5.93865082 -10.39974297]
# state: 21, remaining: 9
# [ 1.14479795 -6.37953565  3.79608274 -6.06360587]
# state: 22, remaining: 8
# [ 1.20407152 -6.49536719  1.84274937 -2.10228541]
# state: 23, remaining: 7
# [ 1.25717528 -6.52460015  0.12247702  1.34934836]
# state: 24, remaining: 6
# [ 1.27527499 -6.48116535 -1.33749621  4.26164484]
# state: 25, remaining: 5
# [ 1.29826975 -6.37367352 -2.72046596  6.97398055]
# state: 26, remaining: 4
# [ 1.30118232 -6.19662179 -3.99222232  9.48238815]
# state: 27, remaining: 3
# [ 1.30620122 -5.97061961 -4.98662085 11.37791822]
# state: 28, remaining: 2
# [ 1.31962949 -5.67815424 -5.58158767 12.47153857]
# state: 29, remaining: 1
# [ 1.35430447 -5.35017443 -5.22333774 11.53451197]
# [[-3.53419751e-01 -2.30131878e+00  4.53975847e+00 -5.87144004e+00]
#  [-1.11792825e-01 -1.98315745e+00  5.18938112e+00 -7.33720170e+00]
#  [-5.07099537e-02 -2.17323859e+00  4.62189421e+00 -5.79537875e+00]
#  [ 1.23644710e-01 -2.18178419e+00  1.59418380e+00  1.09830842e+00]
#  [ 2.00213156e-01 -2.09127507e+00 -6.08454882e-01  5.91700371e+00]
#  [ 2.06211927e-01 -1.93490075e+00 -2.02265371e+00  8.76853027e+00]
#  [ 1.67143423e-01 -1.73300544e+00 -2.61007463e+00  9.66890402e+00]
#  [ 1.03822317e-01 -1.52822375e+00 -2.19284094e+00  8.38028111e+00]
#  [ 3.53381781e-02 -1.35677093e+00 -9.23002781e-01  5.36556902e+00]
#  [-2.00903148e-02 -1.25291057e+00  1.12762046e+00  8.21222291e-01]
#  [-3.90005851e-02 -1.25695465e+00  3.83008636e+00 -4.98737620e+00]
#  [-2.56016838e-02 -1.37641625e+00  6.99466878e+00 -1.16618561e+01]
#  [ 5.18827223e-02 -1.65834805e+00  1.02834902e+01 -1.85266331e+01]
#  [ 1.72521288e-01 -2.08066856e+00  1.34792326e+01 -2.51230046e+01]
#  [ 3.35195106e-01 -2.66907827e+00  1.63387589e+01 -3.10295268e+01]
#  [ 4.05620386e-01 -3.52828792e+00  1.59576769e+01 -2.99746332e+01]
#  [ 4.29067603e-01 -4.37239579e+00  1.42802350e+01 -2.66484149e+01]
#  [ 6.14434715e-01 -4.98030774e+00  1.20333870e+01 -2.23854077e+01]
#  [ 7.73462442e-01 -5.45997096e+00  1.01537053e+01 -1.87976633e+01]
#  [ 9.26739533e-01 -5.86428099e+00  8.11659488e+00 -1.47871040e+01]
#  [ 1.04321424e+00 -6.16573047e+00  5.93865082e+00 -1.03997430e+01]
#  [ 1.14479795e+00 -6.37953565e+00  3.79608274e+00 -6.06360587e+00]
#  [ 1.20407152e+00 -6.49536719e+00  1.84274937e+00 -2.10228541e+00]
#  [ 1.25717528e+00 -6.52460015e+00  1.22477020e-01  1.34934836e+00]
#  [ 1.27527499e+00 -6.48116535e+00 -1.33749621e+00  4.26164484e+00]
#  [ 1.29826975e+00 -6.37367352e+00 -2.72046596e+00  6.97398055e+00]
#  [ 1.30118232e+00 -6.19662179e+00 -3.99222232e+00  9.48238815e+00]
#  [ 1.30620122e+00 -5.97061961e+00 -4.98662085e+00  1.13779182e+01]
#  [ 1.31962949e+00 -5.67815424e+00 -5.58158767e+00  1.24715386e+01]
#  [ 1.35430447e+00 -5.35017443e+00 -5.22333774e+00  1.15345120e+01]]
# animating...
# 30
# state:
# [-0.35341975 -2.30131878  4.53975847 -5.87144004]
# x1: -6.922164, y1: -18.763892, x2: -16.279121, y2: -1.087712

# %%
params = {}
params['obs_w'] = width
params['obs_h'] = width
params['integration_step'] = 0.02
system = Acrobot()

vis = AcrobotVisualizer(system, params)
states = path
actions = controls
print('states:')
print(states)
anim = vis.animate(np.array(states), np.array(actions), obs_list)
HTML(anim.to_html5_video())
#anim.save('acrobot_env%d_path%d.mp4' % (obs_idx, p_idx))
# Out:
# states:
# [array([-0.35341975, -2.30131878,  4.53975847, -5.87144004]), array([-0.11179283, -1.98315745,  5.18938112, -7.3372017 ]), array([-0.05070995, -2.17323859,  4.62189421, -5.79537875]), array([ 0.12364471, -2.18178419,  1.5941838 ,  1.09830842]), array([ 0.20021316, -2.09127507, -0.60845488,  5.91700371]), array([ 0.20621193, -1.93490075, -2.02265371,  8.76853027]), array([ 0.16714342, -1.73300544, -2.61007463,  9.66890402]), array([ 0.10382232, -1.52822375, -2.19284094,  8.38028111]), array([ 0.03533818, -1.35677093, -0.92300278,  5.36556902]), array([-0.02009031, -1.25291057,  1.12762046,  0.82122229]), array([-0.03900059, -1.25695465,  3.83008636, -4.9873762 ]), array([ -0.02560168,  -1.37641625,   6.99466878, -11.6618561 ]), array([  0.05188272,  -1.65834805,  10.28349017, -18.52663308]), array([  0.17252129,  -2.08066856,  13.47923264, -25.12300458]), array([  0.33519511,  -2.66907827,  16.33875887, -31.02952676]), array([  0.40562039,  -3.52828792,  15.95767693, -29.9746332 ]), array([  0.4290676 ,  -4.37239579,  14.280235  , -26.64841493]), array([  0.61443472,  -4.98030774,  12.03338704, -22.38540773]), array([  0.77346244,  -5.45997096,  10.15370532, -18.79766328]), array([  0.92673953,  -5.86428099,   8.11659488, -14.78710397]), array([  1.04321424,  -6.16573047,   5.93865082, -10.39974297]), array([ 1.14479795, -6.37953565,  3.79608274, -6.06360587]), array([ 1.20407152, -6.49536719,  1.84274937, -2.10228541]), array([ 1.25717528, -6.52460015,  0.12247702,  1.34934836]), array([ 1.27527499, -6.48116535, -1.33749621,  4.26164484]), array([ 1.29826975, -6.37367352, -2.72046596,  6.97398055]), array([ 1.30118232, -6.19662179, -3.99222232,  9.48238815]), array([ 1.30620122, -5.97061961, -4.98662085, 11.37791822]), array([ 1.31962949, -5.67815424, -5.58158767, 12.47153857]), array([ 1.35430447, -5.35017443, -5.22333774, 11.53451197])]
# state: 0, remaining: 30
# [-0.35341975 -2.30131878  4.53975847 -5.87144004]
# state: 1, remaining: 29
# [-0.11179283 -1.98315745  5.18938112 -7.3372017 ]
# state: 2, remaining: 28
# [-0.05070995 -2.17323859  4.62189421 -5.79537875]
# state: 3, remaining: 27
# [ 0.12364471 -2.18178419  1.5941838   1.09830842]
# state: 4, remaining: 26
# [ 0.20021316 -2.09127507 -0.60845488  5.91700371]
# state: 5, remaining: 25
# [ 0.20621193 -1.93490075 -2.02265371  8.76853027]
# state: 6, remaining: 24
# [ 0.16714342 -1.73300544 -2.61007463  9.66890402]
# state: 7, remaining: 23
# [ 0.10382232 -1.52822375 -2.19284094  8.38028111]
# state: 8, remaining: 22
# [ 0.03533818 -1.35677093 -0.92300278  5.36556902]
# state: 9, remaining: 21
# [-0.02009031 -1.25291057  1.12762046  0.82122229]
# state: 10, remaining: 20
# [-0.03900059 -1.25695465  3.83008636 -4.9873762 ]
# state: 11, remaining: 19
# [ -0.02560168  -1.37641625   6.99466878 -11.6618561 ]
# state: 12, remaining: 18
# [  0.05188272  -1.65834805  10.28349017 -18.52663308]
# state: 13, remaining: 17
# [  0.17252129  -2.08066856  13.47923264 -25.12300458]
# state: 14, remaining: 16
# [  0.33519511  -2.66907827  16.33875887 -31.02952676]
# state: 15, remaining: 15
# [  0.40562039  -3.52828792  15.95767693 -29.9746332 ]
# state: 16, remaining: 14
# [  0.4290676   -4.37239579  14.280235   -26.64841493]
# state: 17, remaining: 13
# [  0.61443472  -4.98030774  12.03338704 -22.38540773]
# state: 18, remaining: 12
# [  0.77346244  -5.45997096  10.15370532 -18.79766328]
# state: 19, remaining: 11
# [  0.92673953  -5.86428099   8.11659488 -14.78710397]
# state: 20, remaining: 10
# [  1.04321424  -6.16573047   5.93865082 -10.39974297]
# state: 21, remaining: 9
# [ 1.14479795 -6.37953565  3.79608274 -6.06360587]
# state: 22, remaining: 8
# [ 1.20407152 -6.49536719  1.84274937 -2.10228541]
# state: 23, remaining: 7
# [ 1.25717528 -6.52460015  0.12247702  1.34934836]
# state: 24, remaining: 6
# [ 1.27527499 -6.48116535 -1.33749621  4.26164484]
# state: 25, remaining: 5
# [ 1.29826975 -6.37367352 -2.72046596  6.97398055]
# state: 26, remaining: 4
# [ 1.30118232 -6.19662179 -3.99222232  9.48238815]
# state: 27, remaining: 3
# [ 1.30620122 -5.97061961 -4.98662085 11.37791822]
# state: 28, remaining: 2
# [ 1.31962949 -5.67815424 -5.58158767 12.47153857]
# state: 29, remaining: 1
# [ 1.35430447 -5.35017443 -5.22333774 11.53451197]
# [[-3.53419751e-01 -2.30131878e+00  4.53975847e+00 -5.87144004e+00]
#  [-1.11792825e-01 -1.98315745e+00  5.18938112e+00 -7.33720170e+00]
#  [-5.07099537e-02 -2.17323859e+00  4.62189421e+00 -5.79537875e+00]
#  [ 1.23644710e-01 -2.18178419e+00  1.59418380e+00  1.09830842e+00]
#  [ 2.00213156e-01 -2.09127507e+00 -6.08454882e-01  5.91700371e+00]
#  [ 2.06211927e-01 -1.93490075e+00 -2.02265371e+00  8.76853027e+00]
#  [ 1.67143423e-01 -1.73300544e+00 -2.61007463e+00  9.66890402e+00]
#  [ 1.03822317e-01 -1.52822375e+00 -2.19284094e+00  8.38028111e+00]
#  [ 3.53381781e-02 -1.35677093e+00 -9.23002781e-01  5.36556902e+00]
#  [-2.00903148e-02 -1.25291057e+00  1.12762046e+00  8.21222291e-01]
#  [-3.90005851e-02 -1.25695465e+00  3.83008636e+00 -4.98737620e+00]
#  [-2.56016838e-02 -1.37641625e+00  6.99466878e+00 -1.16618561e+01]
#  [ 5.18827223e-02 -1.65834805e+00  1.02834902e+01 -1.85266331e+01]
#  [ 1.72521288e-01 -2.08066856e+00  1.34792326e+01 -2.51230046e+01]
#  [ 3.35195106e-01 -2.66907827e+00  1.63387589e+01 -3.10295268e+01]
#  [ 4.05620386e-01 -3.52828792e+00  1.59576769e+01 -2.99746332e+01]
#  [ 4.29067603e-01 -4.37239579e+00  1.42802350e+01 -2.66484149e+01]
#  [ 6.14434715e-01 -4.98030774e+00  1.20333870e+01 -2.23854077e+01]
#  [ 7.73462442e-01 -5.45997096e+00  1.01537053e+01 -1.87976633e+01]
#  [ 9.26739533e-01 -5.86428099e+00  8.11659488e+00 -1.47871040e+01]
#  [ 1.04321424e+00 -6.16573047e+00  5.93865082e+00 -1.03997430e+01]
#  [ 1.14479795e+00 -6.37953565e+00  3.79608274e+00 -6.06360587e+00]
#  [ 1.20407152e+00 -6.49536719e+00  1.84274937e+00 -2.10228541e+00]
#  [ 1.25717528e+00 -6.52460015e+00  1.22477020e-01  1.34934836e+00]
#  [ 1.27527499e+00 -6.48116535e+00 -1.33749621e+00  4.26164484e+00]
#  [ 1.29826975e+00 -6.37367352e+00 -2.72046596e+00  6.97398055e+00]
#  [ 1.30118232e+00 -6.19662179e+00 -3.99222232e+00  9.48238815e+00]
#  [ 1.30620122e+00 -5.97061961e+00 -4.98662085e+00  1.13779182e+01]
#  [ 1.31962949e+00 -5.67815424e+00 -5.58158767e+00  1.24715386e+01]
#  [ 1.35430447e+00 -5.35017443e+00 -5.22333774e+00  1.15345120e+01]]
# animating...
# 30
# state:
# [-0.35341975 -2.30131878  4.53975847 -5.87144004]
# x1: -6.922164, y1: -18.763892, x2: -16.279121, y2: -1.087712
# state:
# [-0.35341975 -2.30131878  4.53975847 -5.87144004]
# x1: -6.922164, y1: -18.763892, x2: -16.279121, y2: -1.087712
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
params = {}
params['obs_w'] = width
params['obs_h'] = width
params['integration_step'] = 0.02
system = Acrobot()
vis = AcrobotPlotter(system, params)
states = init_path
actions = init_controls
print('states:')
print(states)
vis.animate(np.array(states), np.array(actions), obs_list)

#anim.save('acrobot_env%d_path%d.mp4' % (obs_idx, p_idx))
# Out:
# states:
# [[-0.35341975 -2.30131878  4.53975847 -5.87144004]
#  [-0.26262458 -2.41874758  4.64115216 -5.7919258 ]
#  [-0.16980154 -2.5345861   4.73031167 -5.71129037]
#  [-0.0751953  -2.6488119   4.80281008 -5.63056394]
#  [ 0.0208609  -2.76142318  4.85428252 -5.55082922]
#  [ 0.11794655 -2.87243977  4.88083126 -5.4731153 ]
#  [ 0.21556317 -2.98190207  4.87942984 -5.39826143]
#  [ 0.31315177 -3.0898673   4.84825785 -5.32678028]
#  [ 0.41011693 -3.19640291  4.7869044  -5.25875458]
#  [ 0.50585501 -3.301578    4.69640261 -5.19379499]
#  [ 0.59978307 -3.4054539   4.57909238 -5.13107149]
#  [ 0.69136491 -3.50807533  4.43834228 -5.06941134]
#  [ 0.78013176 -3.60946356  4.27818509 -5.00744017]
#  [ 0.86569546 -3.70961236  4.10292954 -4.94373478]
#  [ 0.94775405 -3.80848705  3.91680495 -4.87695849]
#  [ 1.02609015 -3.90602622  3.72367903 -4.80595922]
#  [ 1.10056373 -4.00214541  3.52686884 -4.72982323]
#  [ 1.17110111 -4.09674187  3.32904565 -4.64788821]
#  [ 1.23768202 -4.18969964  3.13222015 -4.55972635]
#  [ 1.30032642 -4.28089416  2.93778721 -4.46510993]
#  [ 1.35908217 -4.37019636  2.74660753 -4.36397113]
#  [ 1.41401432 -4.45747579  2.55910654 -4.25636402]
#  [ 1.46519645 -4.54260307  2.37537555 -4.14243375]
#  [ 1.51270396 -4.62545174  2.19526561 -4.0223944 ]
#  [ 1.55660927 -4.70589963  2.01846869 -3.89651526]
#  [ 1.59697865 -4.78382993  1.84458429 -3.76511371]
#  [ 1.63387033 -4.85913221  1.67317155 -3.62855255]
#  [ 1.66733376 -4.93170326  1.5037882  -3.4872396 ]
#  [ 1.69740953 -5.00144805  1.33601787 -3.34162741]
#  [ 1.72412989 -5.0682806   1.16948791 -3.19221172]]
# state: 0, remaining: 30
# [-0.35341975 -2.30131878  4.53975847 -5.87144004]
# state: 1, remaining: 29
# [-0.26262458 -2.41874758  4.64115216 -5.7919258 ]
# state: 2, remaining: 28
# [-0.16980154 -2.5345861   4.73031167 -5.71129037]
# state: 3, remaining: 27
# [-0.0751953  -2.6488119   4.80281008 -5.63056394]
# state: 4, remaining: 26
# [ 0.0208609  -2.76142318  4.85428252 -5.55082922]
# state: 5, remaining: 25
# [ 0.11794655 -2.87243977  4.88083126 -5.4731153 ]
# state: 6, remaining: 24
# [ 0.21556317 -2.98190207  4.87942984 -5.39826143]
# state: 7, remaining: 23
# [ 0.31315177 -3.0898673   4.84825785 -5.32678028]
# state: 8, remaining: 22
# [ 0.41011693 -3.19640291  4.7869044  -5.25875458]
# state: 9, remaining: 21
# [ 0.50585501 -3.301578    4.69640261 -5.19379499]
# state: 10, remaining: 20
# [ 0.59978307 -3.4054539   4.57909238 -5.13107149]
# state: 11, remaining: 19
# [ 0.69136491 -3.50807533  4.43834228 -5.06941134]
# state: 12, remaining: 18
# [ 0.78013176 -3.60946356  4.27818509 -5.00744017]
# state: 13, remaining: 17
# [ 0.86569546 -3.70961236  4.10292954 -4.94373478]
# state: 14, remaining: 16
# [ 0.94775405 -3.80848705  3.91680495 -4.87695849]
# state: 15, remaining: 15
# [ 1.02609015 -3.90602622  3.72367903 -4.80595922]
# state: 16, remaining: 14
# [ 1.10056373 -4.00214541  3.52686884 -4.72982323]
# state: 17, remaining: 13
# [ 1.17110111 -4.09674187  3.32904565 -4.64788821]
# state: 18, remaining: 12
# [ 1.23768202 -4.18969964  3.13222015 -4.55972635]
# state: 19, remaining: 11
# [ 1.30032642 -4.28089416  2.93778721 -4.46510993]
# state: 20, remaining: 10
# [ 1.35908217 -4.37019636  2.74660753 -4.36397113]
# state: 21, remaining: 9
# [ 1.41401432 -4.45747579  2.55910654 -4.25636402]
# state: 22, remaining: 8
# [ 1.46519645 -4.54260307  2.37537555 -4.14243375]
# state: 23, remaining: 7
# [ 1.51270396 -4.62545174  2.19526561 -4.0223944 ]
# state: 24, remaining: 6
# [ 1.55660927 -4.70589963  2.01846869 -3.89651526]
# state: 25, remaining: 5
# [ 1.59697865 -4.78382993  1.84458429 -3.76511371]
# state: 26, remaining: 4
# [ 1.63387033 -4.85913221  1.67317155 -3.62855255]
# state: 27, remaining: 3
# [ 1.66733376 -4.93170326  1.5037882  -3.4872396 ]
# state: 28, remaining: 2
# [ 1.69740953 -5.00144805  1.33601787 -3.34162741]
# state: 29, remaining: 1
# [ 1.72412989 -5.0682806   1.16948791 -3.19221172]
# [[-0.35341975 -2.30131878  4.53975847 -5.87144004]
#  [-0.26262458 -2.41874758  4.64115216 -5.7919258 ]
#  [-0.16980154 -2.5345861   4.73031167 -5.71129037]
#  [-0.0751953  -2.6488119   4.80281008 -5.63056394]
#  [ 0.0208609  -2.76142318  4.85428252 -5.55082922]
#  [ 0.11794655 -2.87243977  4.88083126 -5.4731153 ]
#  [ 0.21556317 -2.98190207  4.87942984 -5.39826143]
#  [ 0.31315177 -3.0898673   4.84825785 -5.32678028]
#  [ 0.41011693 -3.19640291  4.7869044  -5.25875458]
#  [ 0.50585501 -3.301578    4.69640261 -5.19379499]
#  [ 0.59978307 -3.4054539   4.57909238 -5.13107149]
#  [ 0.69136491 -3.50807533  4.43834228 -5.06941134]
#  [ 0.78013176 -3.60946356  4.27818509 -5.00744017]
#  [ 0.86569546 -3.70961236  4.10292954 -4.94373478]
#  [ 0.94775405 -3.80848705  3.91680495 -4.87695849]
#  [ 1.02609015 -3.90602622  3.72367903 -4.80595922]
#  [ 1.10056373 -4.00214541  3.52686884 -4.72982323]
#  [ 1.17110111 -4.09674187  3.32904565 -4.64788821]
#  [ 1.23768202 -4.18969964  3.13222015 -4.55972635]
#  [ 1.30032642 -4.28089416  2.93778721 -4.46510993]
#  [ 1.35908217 -4.37019636  2.74660753 -4.36397113]
#  [ 1.41401432 -4.45747579  2.55910654 -4.25636402]
#  [ 1.46519645 -4.54260307  2.37537555 -4.14243375]
#  [ 1.51270396 -4.62545174  2.19526561 -4.0223944 ]
#  [ 1.55660927 -4.70589963  2.01846869 -3.89651526]
#  [ 1.59697865 -4.78382993  1.84458429 -3.76511371]
#  [ 1.63387033 -4.85913221  1.67317155 -3.62855255]
#  [ 1.66733376 -4.93170326  1.5037882  -3.4872396 ]
#  [ 1.69740953 -5.00144805  1.33601787 -3.34162741]
#  [ 1.72412989 -5.0682806   1.16948791 -3.19221172]]
# animating...
# 30
# state:
# [-0.35341975 -2.30131878  4.53975847 -5.87144004]
# x1: -6.922164, y1: -18.763892, x2: -16.279121, y2: -1.087712

# %%
params = {}
params['obs_w'] = width
params['obs_h'] = width
params['integration_step'] = 0.02
system = Acrobot()
vis = AcrobotVisualizer(system, params)
states = init_path
actions = init_controls
print('states:')
print(states)
anim = vis.animate(np.array(states), np.array(actions), obs_list)
HTML(anim.to_html5_video())
#anim.save('acrobot_env%d_path%d.mp4' % (obs_idx, p_idx))
# Out:
# states:
# [[-0.35341975 -2.30131878  4.53975847 -5.87144004]
#  [-0.26262458 -2.41874758  4.64115216 -5.7919258 ]
#  [-0.16980154 -2.5345861   4.73031167 -5.71129037]
#  [-0.0751953  -2.6488119   4.80281008 -5.63056394]
#  [ 0.0208609  -2.76142318  4.85428252 -5.55082922]
#  [ 0.11794655 -2.87243977  4.88083126 -5.4731153 ]
#  [ 0.21556317 -2.98190207  4.87942984 -5.39826143]
#  [ 0.31315177 -3.0898673   4.84825785 -5.32678028]
#  [ 0.41011693 -3.19640291  4.7869044  -5.25875458]
#  [ 0.50585501 -3.301578    4.69640261 -5.19379499]
#  [ 0.59978307 -3.4054539   4.57909238 -5.13107149]
#  [ 0.69136491 -3.50807533  4.43834228 -5.06941134]
#  [ 0.78013176 -3.60946356  4.27818509 -5.00744017]
#  [ 0.86569546 -3.70961236  4.10292954 -4.94373478]
#  [ 0.94775405 -3.80848705  3.91680495 -4.87695849]
#  [ 1.02609015 -3.90602622  3.72367903 -4.80595922]
#  [ 1.10056373 -4.00214541  3.52686884 -4.72982323]
#  [ 1.17110111 -4.09674187  3.32904565 -4.64788821]
#  [ 1.23768202 -4.18969964  3.13222015 -4.55972635]
#  [ 1.30032642 -4.28089416  2.93778721 -4.46510993]
#  [ 1.35908217 -4.37019636  2.74660753 -4.36397113]
#  [ 1.41401432 -4.45747579  2.55910654 -4.25636402]
#  [ 1.46519645 -4.54260307  2.37537555 -4.14243375]
#  [ 1.51270396 -4.62545174  2.19526561 -4.0223944 ]
#  [ 1.55660927 -4.70589963  2.01846869 -3.89651526]
#  [ 1.59697865 -4.78382993  1.84458429 -3.76511371]
#  [ 1.63387033 -4.85913221  1.67317155 -3.62855255]
#  [ 1.66733376 -4.93170326  1.5037882  -3.4872396 ]
#  [ 1.69740953 -5.00144805  1.33601787 -3.34162741]
#  [ 1.72412989 -5.0682806   1.16948791 -3.19221172]]
# state: 0, remaining: 30
# [-0.35341975 -2.30131878  4.53975847 -5.87144004]
# state: 1, remaining: 29
# [-0.26262458 -2.41874758  4.64115216 -5.7919258 ]
# state: 2, remaining: 28
# [-0.16980154 -2.5345861   4.73031167 -5.71129037]
# state: 3, remaining: 27
# [-0.0751953  -2.6488119   4.80281008 -5.63056394]
# state: 4, remaining: 26
# [ 0.0208609  -2.76142318  4.85428252 -5.55082922]
# state: 5, remaining: 25
# [ 0.11794655 -2.87243977  4.88083126 -5.4731153 ]
# state: 6, remaining: 24
# [ 0.21556317 -2.98190207  4.87942984 -5.39826143]
# state: 7, remaining: 23
# [ 0.31315177 -3.0898673   4.84825785 -5.32678028]
# state: 8, remaining: 22
# [ 0.41011693 -3.19640291  4.7869044  -5.25875458]
# state: 9, remaining: 21
# [ 0.50585501 -3.301578    4.69640261 -5.19379499]
# state: 10, remaining: 20
# [ 0.59978307 -3.4054539   4.57909238 -5.13107149]
# state: 11, remaining: 19
# [ 0.69136491 -3.50807533  4.43834228 -5.06941134]
# state: 12, remaining: 18
# [ 0.78013176 -3.60946356  4.27818509 -5.00744017]
# state: 13, remaining: 17
# [ 0.86569546 -3.70961236  4.10292954 -4.94373478]
# state: 14, remaining: 16
# [ 0.94775405 -3.80848705  3.91680495 -4.87695849]
# state: 15, remaining: 15
# [ 1.02609015 -3.90602622  3.72367903 -4.80595922]
# state: 16, remaining: 14
# [ 1.10056373 -4.00214541  3.52686884 -4.72982323]
# state: 17, remaining: 13
# [ 1.17110111 -4.09674187  3.32904565 -4.64788821]
# state: 18, remaining: 12
# [ 1.23768202 -4.18969964  3.13222015 -4.55972635]
# state: 19, remaining: 11
# [ 1.30032642 -4.28089416  2.93778721 -4.46510993]
# state: 20, remaining: 10
# [ 1.35908217 -4.37019636  2.74660753 -4.36397113]
# state: 21, remaining: 9
# [ 1.41401432 -4.45747579  2.55910654 -4.25636402]
# state: 22, remaining: 8
# [ 1.46519645 -4.54260307  2.37537555 -4.14243375]
# state: 23, remaining: 7
# [ 1.51270396 -4.62545174  2.19526561 -4.0223944 ]
# state: 24, remaining: 6
# [ 1.55660927 -4.70589963  2.01846869 -3.89651526]
# state: 25, remaining: 5
# [ 1.59697865 -4.78382993  1.84458429 -3.76511371]
# state: 26, remaining: 4
# [ 1.63387033 -4.85913221  1.67317155 -3.62855255]
# state: 27, remaining: 3
# [ 1.66733376 -4.93170326  1.5037882  -3.4872396 ]
# state: 28, remaining: 2
# [ 1.69740953 -5.00144805  1.33601787 -3.34162741]
# state: 29, remaining: 1
# [ 1.72412989 -5.0682806   1.16948791 -3.19221172]
# [[-0.35341975 -2.30131878  4.53975847 -5.87144004]
#  [-0.26262458 -2.41874758  4.64115216 -5.7919258 ]
#  [-0.16980154 -2.5345861   4.73031167 -5.71129037]
#  [-0.0751953  -2.6488119   4.80281008 -5.63056394]
#  [ 0.0208609  -2.76142318  4.85428252 -5.55082922]
#  [ 0.11794655 -2.87243977  4.88083126 -5.4731153 ]
#  [ 0.21556317 -2.98190207  4.87942984 -5.39826143]
#  [ 0.31315177 -3.0898673   4.84825785 -5.32678028]
#  [ 0.41011693 -3.19640291  4.7869044  -5.25875458]
#  [ 0.50585501 -3.301578    4.69640261 -5.19379499]
#  [ 0.59978307 -3.4054539   4.57909238 -5.13107149]
#  [ 0.69136491 -3.50807533  4.43834228 -5.06941134]
#  [ 0.78013176 -3.60946356  4.27818509 -5.00744017]
#  [ 0.86569546 -3.70961236  4.10292954 -4.94373478]
#  [ 0.94775405 -3.80848705  3.91680495 -4.87695849]
#  [ 1.02609015 -3.90602622  3.72367903 -4.80595922]
#  [ 1.10056373 -4.00214541  3.52686884 -4.72982323]
#  [ 1.17110111 -4.09674187  3.32904565 -4.64788821]
#  [ 1.23768202 -4.18969964  3.13222015 -4.55972635]
#  [ 1.30032642 -4.28089416  2.93778721 -4.46510993]
#  [ 1.35908217 -4.37019636  2.74660753 -4.36397113]
#  [ 1.41401432 -4.45747579  2.55910654 -4.25636402]
#  [ 1.46519645 -4.54260307  2.37537555 -4.14243375]
#  [ 1.51270396 -4.62545174  2.19526561 -4.0223944 ]
#  [ 1.55660927 -4.70589963  2.01846869 -3.89651526]
#  [ 1.59697865 -4.78382993  1.84458429 -3.76511371]
#  [ 1.63387033 -4.85913221  1.67317155 -3.62855255]
#  [ 1.66733376 -4.93170326  1.5037882  -3.4872396 ]
#  [ 1.69740953 -5.00144805  1.33601787 -3.34162741]
#  [ 1.72412989 -5.0682806   1.16948791 -3.19221172]]
# animating...
# 30
# state:
# [-0.35341975 -2.30131878  4.53975847 -5.87144004]
# x1: -6.922164, y1: -18.763892, x2: -16.279121, y2: -1.087712
# state:
# [-0.35341975 -2.30131878  4.53975847 -5.87144004]
# x1: -6.922164, y1: -18.763892, x2: -16.279121, y2: -1.087712
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
# visualize point cloud
import matplotlib.pyplot as plt
print(obc_list.shape)
obc_all = np.concatenate(obc_list_total[obs_idx], axis=0)
print(obc_all.shape)
plt.scatter(obc_all[:,0], obc_all[:,1])
plt.show()
# Out:
# (2, 1400, 2)
# (2800, 2)

# %%
for i in range(2):
    obc_all = np.concatenate(obc_list_total[i], axis=0)
    print(obc_all.shape)
    plt.scatter(obc_all[:,0], obc_all[:,1])
    plt.show()
# Out:
# (2800, 2)
# (2800, 2)
